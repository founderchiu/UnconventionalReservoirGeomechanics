# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import numpy as np

# %%
BarnettShaleDenLog=pd.read_csv('GP208_HW1_Barnett_Density_Log.txt',sep="\t",header=0)

# %%
x=BarnettShaleDenLog['Density (g/cc)']
y=BarnettShaleDenLog['Depth (ft)']

plt.plot(x,y)
plt.gca().invert_yaxis()

# %%
BarnettShaleDenLog[BarnettShaleDenLog['Depth (ft)']==5500]
# Out:
#        Depth (ft)  Density (g/cc)
# 10810      5500.0           2.594

# %%
Sv5500BS=5500*2.594*0.433*0.00689476
Sv5500BS
# Out:
# 42.59314521836

# %%
SP5500BS=5500*0.433*0.00689476
SP5500BS
# Out:
# 16.41987094

# %%
Sv5500_gradient=2.594*0.433
Sv5500_gradient
# Out:
# 1.123202

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SHMax=((0.6**2+1)**0.5+0.6)**2*(Sv5500BS-5500*0.5*0.00689476)+5500*0.5*0.00689476
SHMax
# Out:
# 92.68065520690698

# %%
Shmin=(Sv5500BS-5500*0.5*0.00689476)/((0.6**2+1)**0.5+0.6)**2+5500*0.5*0.00689476
Shmin
# Out:
# 26.536514744251416

# %%
SHMax_ISIP=((0.6**2+1)**0.5+0.6)**2*(38-5500*0.5*0.00689476)+5500*0.5*0.00689476
SHMax_ISIP
# Out:
# 78.35266731589677

# %%
SHMax_ISIP=((0.6**2+1)**0.5+0.6)**2*(28-5500*0.5*0.00689476)+5500*0.5*0.00689476
SHMax_ISIP
# Out:
# 47.158382768268055

# %% [markdown]
# Sp gradient=0.7 psi/ft

# %%
SHMax=((0.6**2+1)**0.5+0.6)**2*(Sv5500BS-5500*0.7*0.00689476)+5500*0.7*0.00689476
SHMax
# Out:
# 76.60640962087004

# %%
Shmin=(Sv5500BS-5500*0.7*0.00689476)/((0.6**2+1)**0.5+0.6)**2+5500*0.7*0.00689476
Shmin
# Out:
# 31.68946049028836

# %%
SHMax_ISIP=((0.6**2+1)**0.5+0.6)**2*(38-5500*0.7*0.00689476)+5500*0.7*0.00689476
SHMax_ISIP
# Out:
# 62.27842172985983
